# %%
import pandas as pd

# %%
df_lid =pd.read_excel('./test_lid.xlsx')
df_sdelka =pd.read_excel('./test_sdelka.xlsx')

# %%
df_lid.head(5)
# Out:
#       ID                    Стадия                   Название лида  \
# 0  15435                     Дубль  ✞︎𝕍𝕚𝕥𝕒𝕝𝕚𝕜✞︎ - Instagram Direct
# 1  15434                  Нет авто   Лид с формы регистрации MyFin
# 2  15433        Не оставлял заявку   Лид с формы регистрации MyFin
# 3  15432                 Новый лид         Лид с формы регистрации
# 4  15431  Не дожат (отказ клиента)         Лид с формы регистрации
#
#         Дата создания          Источник      Дата изменения  \
# 0 2025-07-11 23:43:00  Instagram Direct 2025-07-12 08:49:00
# 1 2025-07-11 23:41:00             MYFIN 2025-07-14 10:04:00
# 2 2025-07-11 23:41:00             MYFIN 2025-07-14 12:37:00
# 3 2025-07-11 23:20:00    Сайт dzengo.by 2025-07-11 23:20:00
# 4 2025-07-11 23:08:00    Сайт dzengo.by 2025-07-12 17:45:00
#
#                Комментарий  Сумма             Валюта Повторный лид UTM Source  \
# 0                      NaN    0.0  Белорусский рубль             N        NaN
# 1  Лид с формы регистрации    0.0  Белорусский рубль             Y      myfin
# 2  Лид с формы регистрации    0.0  Белорусский рубль             N      myfin
# 3  Лид с формы регистрации    0.0  Белорусский рубль             N     google
# 4  Лид с формы регистрации    0.0  Белорусский рубль             N     google
#
#   UTM Medium             UTM Campaign   UTM Content                UTM Term  \
# 0        NaN                      NaN           NaN                     NaN
# 1    lidform                      lid           NaN                     NaN
# 2    lidform                      lid           NaN                     NaN
# 3        cpc  by_dzengo_google_search  {ad_content}           деньги онлайн
# 4        cpc  by_dzengo_google_search  {ad_content}  деньги в долг на карту
#
#    ID контакта
# 0          NaN
# 1       2314.0
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df_sdelka.head(5)
# Out:
#        ID Воронка Повторная сделка Повторное обращение   Стадия сделки  \
# 0  2265.0  Сделки                N                   N     Отказ по КИ
# 1  2264.0  Сделки                Y                   N   Двойной залог
# 2  2262.0  Сделки                Y                   N  Сделка успешна
# 3  2257.0  Сделки                Y                   N  Сделка успешна
# 4  2256.0  Сделки                N                   N     Отказ по КИ
#
#     Сумма             Валюта       Дата создания    Кем создана  \
# 0   400.0  Белорусский рубль 2025-07-11 18:38:00  bitrix24admin
# 1   600.0  Белорусский рубль 2025-07-11 18:16:00  bitrix24admin
# 2   600.0  Белорусский рубль 2025-07-11 17:38:00  bitrix24admin
# 3  2000.0  Белорусский рубль 2025-07-11 15:41:00  bitrix24admin
# 4  3000.0  Белорусский рубль 2025-07-11 15:41:00  bitrix24admin
#
#        Дата изменения  ...  Марка авто Модель авто Год выпуска    Пробег  \
# 0 2025-07-12 10:10:00  ...        Saab         900      1994.0  237893.0
# 1 2025-07-13 15:49:00  ...  Lada (ВАЗ)      Granta      2023.0   15000.0
# 2 2025-07-12 18:02:00  ...        Ford      Mondeo      1993.0   10000.0
# 3 2025-07-13 11:05:00  ...        Ford      Mondeo      2001.0  460000.0
# 4 2025-07-14 09:03:00  ...  Lada (ВАЗ)        2106      1990.0   15028.0
#
#            VIN номер Срок займа в мес.                   Сфера деятельности  \
# 0  YS3DC55A7R2004662              36.0  Сельское, лесное и рыбное хозяйство
# 1  XTA219140R0516885               1.0            Транспортная деятельность
# 2  WF0AXXGBBAPA64226               1.0                       Промышленность
# 3  WF05XXGBB51E46488               6.0    Предоставление прочих видов услуг
# 4  XTA210630L2385734              36.0             Государственный служащий
#
#   Желаемая сумма (д) Желаемый срок (д)              Цель займа
# 0      2 000.00 руб.              36.0    Ремонт авто/квартиры
# 1        600.00 руб.               1.0  Рефинансирование/долги
# 2      1 500.00 руб.              35.0    Ремонт авто/квартиры
# 3      2 000.00 руб.               6.0  Рефинансирование/долги
# 4     10 000.00 руб.              36.0                     NaN
#
# [5 rows x 21 columns]

# %%
df_sdelka.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50 non-null     float64
#  1   Воронка              50 non-null     str
#  2   Повторная сделка     50 non-null     str
#  3   Повторное обращение  50 non-null     str
#  4   Стадия сделки        50 non-null     str
#  5   Сумма                50 non-null     float64
#  6   Валюта               50 non-null     str
#  7   Дата создания        50 non-null     datetime64[us]
#  8   Кем создана          50 non-null     str
#  9   Дата изменения       50 non-null     datetime64[us]
#  10  ID контакта          50 non-null     float64
#  11  Марка авто           50 non-null     str
#  12  Модель авто          50 non-null     object
#  13  Год выпуска          50 non-null     float64
#  14  Пробег               50 non-null     float64
#  15  VIN номер            50 non-null     str
#  16  Срок займа в мес.    50 non-null     float64
#  17  Сфера деятельности   48 non-null     str
#  18  Желаемая сумма (д)   50 non-null     str
#  19  Желаемый срок (д)    50 non-null     float64
#  20  Цель займа           42 non-null     str
# dtypes: datetime64[us](2), float64(7), object(1), str(11)
# memory usage: 8.5+ KB

# %%
df_lid.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              624 non-null    int64
#  1   Стадия          624 non-null    str
#  2   Название лида   624 non-null    str
#  3   Дата создания   624 non-null    datetime64[us]
#  4   Источник        539 non-null    str
#  5   Дата изменения  624 non-null    datetime64[us]
#  6   Комментарий     376 non-null    str
#  7   Сумма           624 non-null    float64
#  8   Валюта          624 non-null    str
#  9   Повторный лид   624 non-null    str
#  10  UTM Source      295 non-null    str
#  11  UTM Medium      268 non-null    str
#  12  UTM Campaign    268 non-null    str
#  13  UTM Content     172 non-null    str
#  14  UTM Term        175 non-null    str
#  15  ID контакта     184 non-null    float64
# dtypes: datetime64[us](2), float64(2), int64(1), str(11)
# memory usage: 78.1 KB

# %%
df_lid['ID'].value_counts()
# Out:
# ID
# 15435    1
# 15434    1
# 15433    1
# 15432    1
# 15431    1
#         ..
# 14802    1
# 14801    1
# 14800    1
# 14799    1
# 14798    1
# Name: count, Length: 624, dtype: int64

# %%
df_sdelka['ID контакта'].value_counts()
# Out:
# ID контакта
# 2254.0    2
# 2208.0    2
# 1562.0    2
# 2307.0    1
# 1121.0    1
# 553.0     1
# 2303.0    1
# 1238.0    1
# 1274.0    1
# 684.0     1
# 1018.0    1
# 1187.0    1
# 2236.0    1
# 2298.0    1
# 2296.0    1
# 2297.0    1
# 790.0     1
# 962.0     1
# 2285.0    1
# 2177.0    1
# 671.0     1
# 2034.0    1
# 122.0     1
# 2288.0    1
# 1974.0    1
# 2281.0    1
# 355.0     1
# 2277.0    1
# 398.0     1
# 2271.0    1
# 2267.0    1
# 2263.0    1
# 332.0     1
# 620.0     1
# 1217.0    1
# 2262.0    1
# 2256.0    1
# 581.0     1
# 2253.0    1
# 2252.0    1
# 2251.0    1
# 1543.0    1
# 1990.0    1
# 2223.0    1
# 1028.0    1
# 2239.0    1
# 2209.0    1
# Name: count, dtype: int64

# %%
df_lid['Стадия'].value_counts()
# Out:
# Стадия
# Дубль                         221
# Нет связи                      78
# Нет авто                       72
# Некачественный лид             63
# Заявка оформлена               41
# Не дожат (отказ клиента)       33
# Новый лид                      23
# Оформил самостоятельно         22
# Лид в работе                   15
# Не оставлял заявку             13
# Перестал выходить на связь     11
# Тесты (ЛЕНА)                    9
# Не актуально                    6
# Качественные лиды               6
# Не звонить                      5
# Регистрация начата              3
# В лизинге                       2
# В ожидании                      1
# Name: count, dtype: int64

# %%
df_lid_del_dubl=df_lid[df_lid['Стадия']!='Дубль']

# %% [markdown]
# Если сделать группировку по полю Стадия, там есть гуппа "Дубль", я предполагаю, что это уже готовая метка на дубль, следовательно строки с такой меткой я удаляю
#
# ![image.png](attachment:f77f1214-03ee-4cbd-8575-e6f0f1497d40.png)
#
# из скрина видно , что лид дублируется (хотя ID разный !!!, возможно просто идентификатор строки)

# %% [markdown]
# Так же исходя из таблиц, можно сделать join по полю ID контакта

# %%
df_all =

# %% [markdown]
# Какие источники лидогенерации работают эффективнее?

# %%
df_lid_del_dubl['Источник'].value_counts()
# Out:
# Источник
# Сайт dzengo.by                  184
# Instagram Direct                 86
# MYFIN                            20
# Виджет на сайте (онлайн чат)     15
# Звонок                           13
# TelegramBOT                      13
# ViberBOT                          6
# Facebook                          2
# AB Marketing                      2
# Name: count, dtype: int64

# %% [markdown]
# Как можно охарактеризовать целевую аудиторию?

# %% [markdown]
# Чтобы ответить на данный вопрос, необходимо подробно изучить таблицы (колонки)
